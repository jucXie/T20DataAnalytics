# %%
pip install adjustText
# Out:
# ...
#
# ...

# %% [markdown]
# Match Summary

# %%
import pandas as pd
df_match = pd.read_csv('E:\\BSc.IT\\TY\\DS Project\\data\\match_summary.csv')
df_match.shape
# Out:
# (45, 8)

# %%
df_match.head(3)
# Out:
#          team1        team2       winner     margin   ground   matchDate  \
# 0      Namibia    Sri Lanka      Namibia    55 runs  Geelong  2022-10-16
# 1  Netherlands       U.A.E.  Netherlands  3 wickets  Geelong  2022-10-16
# 2     Scotland  West Indies     Scotland    42 runs   Hobart  2022-10-17
#
#       match_id      stage
# 0  T20I # 1823  Qualifier
# 1  T20I # 1825  Qualifier
# 2  T20I # 1826  Qualifier

# %%
df_match['match'] = df_match['team1'] + " Vs " + df_match['team2']
df_match.head()
# Out:
#          team1        team2       winner     margin   ground   matchDate  \
# 0      Namibia    Sri Lanka      Namibia    55 runs  Geelong  2022-10-16
# 1  Netherlands       U.A.E.  Netherlands  3 wickets  Geelong  2022-10-16
# 2     Scotland  West Indies     Scotland    42 runs   Hobart  2022-10-17
# 3      Ireland     Zimbabwe     Zimbabwe    31 runs   Hobart  2022-10-17
# 4      Namibia  Netherlands  Netherlands  5 wickets  Geelong  2022-10-18
#
#       match_id      stage                    match
# 0  T20I # 1823  Qualifier     Namibia Vs Sri Lanka
# 1  T20I # 1825  Qualifier    Netherlands Vs U.A.E.
# 2  T20I # 1826  Qualifier  Scotland Vs West Indies
# 3  T20I # 1828  Qualifier      Ireland Vs Zimbabwe
# 4  T20I # 1830  Qualifier   Namibia Vs Netherlands

# %% [markdown]
# Batting Summary

# %%
df_batting = pd.read_csv('E:\\BSc.IT\\TY\\DS Project\\data\\batting_summary.csv')
df_batting.head(11)
# Out:
#                    match teamInnings  battingPos             batsmanName  \
# 0   Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1   Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2   Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3   Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4   Namibia Vs Sri Lanka     Namibia           5         Gerhard Erasmus
# 5   Namibia Vs Sri Lanka     Namibia           6            Jan Frylinck
# 6   Namibia Vs Sri Lanka     Namibia           7             David Wiese
# 7   Namibia Vs Sri Lanka     Namibia           8                 JJ Smit
# 8   Namibia Vs Sri Lanka   Sri Lanka           1         Pathum Nissanka
# 9   Namibia Vs Sri Lanka   Sri Lanka           2            Kusal Mendis
# 10  Namibia Vs Sri Lanka   Sri Lanka           3     Dhananjaya de Silva
#
#     runs  balls  fours  sixes      SR     match_id  out
# ...

# %%
df_batting.dtypes
# Out:
# match          object
# teamInnings    object
# battingPos      int64
# batsmanName    object
# runs            int64
# balls           int64
# fours           int64
# sixes           int64
# SR             object
# match_id       object
# out             int64
# dtype: object

# %%
df_batting.shape
# Out:
# (699, 11)

# %%
#BoundaryRuns
df_batting['boundary_runs'] = df_batting['fours']*4 + df_batting['sixes']*6
df_batting.head()
# Out:
#                   match teamInnings  battingPos             batsmanName  runs  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen     3
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock     9
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton    20
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard    26
# 4  Namibia Vs Sri Lanka     Namibia           5         Gerhard Erasmus    20
#
#    balls  fours  sixes      SR     match_id  out  boundary_runs
# 0      6      0      0   50.00  T20I # 1823    1              0
# 1      9      1      0  100.00  T20I # 1823    1              4
# 2     12      1      2  166.66  T20I # 1823    1             16
# 3     24      2      0  108.33  T20I # 1823    1              8
# 4     24      0      0   83.33  T20I # 1823    1              0

# %%
import matplotlib.pyplot as plt

# Create a scatter plot
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.scatter(df_batting['battingPos'], df_batting['boundary_runs'])
plt.xlabel('Batting Position')
plt.ylabel('Boundary Runs')
plt.title('Batting Position vs. Boundary Runs')
plt.grid(False)
plt.show()

# %%
#df_merge=pd.merge(df_batting,df_match,on='match_id')

df_merge = pd.merge(df_batting,df_match,on='match')
df_merge.head()
# Out:
#                   match teamInnings  battingPos             batsmanName  runs  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen     3
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock     9
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton    20
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard    26
# 4  Namibia Vs Sri Lanka     Namibia           5         Gerhard Erasmus    20
#
#    balls  fours  sixes      SR   match_id_x  out  boundary_runs    team1  \
# 0      6      0      0   50.00  T20I # 1823    1              0  Namibia
# 1      9      1      0  100.00  T20I # 1823    1              4  Namibia
# 2     12      1      2  166.66  T20I # 1823    1             16  Namibia
# 3     24      2      0  108.33  T20I # 1823    1              8  Namibia
# 4     24      0      0   83.33  T20I # 1823    1              0  Namibia
#
# ...

# %%
import numpy as np
#df_merge.groupby(['batsmanName']).agg({'runs': 'sum', 'out': 'sum', 'balls': 'sum', 'boundary_runs': 'sum','battingPos':'sum','match_id':'count'})
#df_merge.head()
df = df_merge.groupby(['batsmanName']).agg({'runs': 'sum', 'out': 'sum', 'balls': 'sum', 'boundary_runs': 'sum','battingPos':'sum','match_id_x':'count'})
df.head()
#df_merge['Batting_Avg'] =  np.divide(Total_Runs['runs'],Total_Runs['out']).replace([np.inf,-np.inf],0).round(2)
#Total_Runs['Strike_Rate'] = ((Total_Runs['runs'] / Total_Runs['balls']).fillna(0) * 100).round(2)

# df_merge['Batting_Avg'] = np.divide(df_merge['runs'],df_merge['out']).replace([np.inf,-np.inf],0).round(2)
# df_merge['Strike_Rate'] = ((df_merge['runs'] / df_merge['balls']).fillna(0) * 100).round(2)
# df_merge['boundaryPerc'] = ((df_merge['boundary_runs']/df_merge['runs'])*100).round(2)
# df_merge['avg_battingPos'] = np.ceil(df_merge['battingPos']/df_merge['match_id'])

# df_merge.loc[(df_merge['Batting_Avg']>30) & (df_merge['Strike_Rate']>140) & (df_merge['inningsBatted']>3) & (df_merge['boundaryPerc']>50.00) & (df_merge['avg_battingPos']<4),['runs','out','Batting_Avg','match_id','matchDate']]
# Out:
#                   runs  out  balls  boundary_runs  battingPos  match_id_x
# batsmanName
# Aaron Finch         63    1     44             38           2           1
# Aayan Afzal Khan    19    1     21              4           7           1
# Adam Zampa           1    0      1              0          10           1
# Afif Hossain        91    2     66             42          15           3
# Aiden Markram       89    3     68             54          12           3

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#         batsmanName  runs  out  balls  boundary_runs  battingPos  match_id_x
# 0       Aaron Finch    63    1     44             38           2           1
# 1  Aayan Afzal Khan    19    1     21              4           7           1
# 2        Adam Zampa     1    0      1              0          10           1
# 3      Afif Hossain    91    2     66             42          15           3
# 4     Aiden Markram    89    3     68             54          12           3

# %%
# df['Batting_Avg'] = np.divide(df['runs'],df['out']).replace([np.inf,-np.inf],0).round(2)
# df['Strike_Rate'] = ((df['runs'] / df['balls']).fillna(0) * 100).round(2)
# df['boundaryPerc'] = ((df['Boundary_Runs']/df['runs'])*100).round(2)
# df['avg_battingPos'] = np.ceil(df['battingPos']/df['match_id_x'])
# batting_match=df.loc[(df['Batting_Avg']>30) & (df['Strike_Rate']>140) & (df['match_id_x']>3) & (df['boundaryPerc']>50.00) & (df['avg_battingPos']<4),['runs','out','Batting_Avg','match_id','matchDate']]
# batting_match

# %%
date = df_merge['matchDate']
match_dates = date.to_list()
df = df_merge.loc[df_merge['stage']=="Qualifier",['matchDate','Batting_Avg']]
df
a = df.groupby(by='matchDate').mean('Batting_Avg')
a.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 3
#       1 date = df_merge['matchDate']
#       2 match_dates = date.to_list()
# ----> 3 df = df_merge.loc[df_merge['stage']=="Qualifier",['matchDate','Batting_Avg']]
#       4 df
#       5 a = df.groupby(by='matchDate').mean('Batting_Avg')
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
# ...

# %% [markdown]
# groupby batsman's names to show total run's scored, number of times a batsman got dismissed, total number of runs scored by boundary, total balls faced by a batsman...

# %%
Total_Runs = df_batting.groupby(['batsmanName']).agg({'runs': 'sum', 'out': 'sum', 'balls': 'sum', 'boundary_runs': 'sum','battingPos':'sum','match_id':'count'})
Total_Runs.tail(15)
# Out:
#                             runs  out  balls  boundary_runs  battingPos  \
# batsmanName
# Tom Cooper                   107    8    103             46          34
# Tony Munyonga                  7    2     10              4           9
# Tristan Stubbs                31    3     31             14          16
# Usman Ghani                   59    3     64             26           8
# Vikramjit Singh               57    5     62             32           7
# Virat Kohli                  296    3    217            148          18
# Vriitya Aravind               48    3     71             12          11
# Wanindu Hasaranga de Silva    25    5     34              8          43
# Wayne Parnell                  5    2     13              0          28
# Wellington Masakadza           1    1      7              0           8
# Wessly Madhevere             106    7     83             72          16
# Yasir Ali                      5    2      9              0          19
# ...

# %% [markdown]
# 1) Total_runs -> Total number of runs scored by the batsman

# %%
#Total_Runs = df_batting.groupby(['batsmanName']).sum()
#Total_Runs.tail(15)
#Total_Runs.iloc[:]['runs']
#Total_Runs['runs'].iloc[-35:-5]
#Total_Runs['runs']

player_runScored = Total_Runs.loc[Total_Runs['runs']>150,['runs']]
player_runScored
# Out:
#                        runs
# batsmanName
# Alex Hales              212
# Andy Balbirnie          153
# Colin Ackermann         165
# Dhananjaya de Silva     177
# Glenn Phillips          201
# Jos Buttler             225
# Kane Williamson         178
# Kusal Mendis            223
# Lorcan Tucker           204
# Max O'Dowd              242
# Mohammad Rizwan         175
# Najmul Hossain Shanto   180
# Pathum Nissanka         214
# Paul Stirling           170
# Sean Williams           155
# Shan Masood             175
# Sikandar Raza           219
# Suryakumar Yadav        239
# Virat Kohli             296

# %%
from matplotlib import pyplot as plt
player_runScored['runs'].plot(kind='bar')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Virat Kohli	-> 296 runs
#
# Suryakumar Yadav -> 239

# %% [markdown]
# 2) Total_inningsBatted -> Total number of innings a batsman got a chance to bat

# %%
#Total_inningsBatted = df_batting.groupby(['batsmanName']).count()
#Total_inningsBatted.head(5)
#Total_inningsBatted.loc[:]['match_id']
Total_Runs['match_id'].iloc[-15:]
# Out:
# batsmanName
# Tom Cooper                    8
# Tony Munyonga                 2
# Tristan Stubbs                3
# Usman Ghani                   3
# Vikramjit Singh               5
# Virat Kohli                   6
# Vriitya Aravind               3
# Wanindu Hasaranga de Silva    6
# Wayne Parnell                 4
# Wellington Masakadza          1
# Wessly Madhevere              8
# Yasir Ali                     3
# Zahoor Khan                   1
# Zane Green                    1
# Zawar Farid                   1
# Name: match_id, dtype: int64

# %% [markdown]
# 3) Total_inningsDismissed -> To find the number of innings batsman got out

# %%
# Total_inningsDismissed = df_batting.groupby(['batsmanName']).sum('out')
# Total_inningsDismissed.tail(30) 
Total_Runs.iloc[:]['out'].tail(12)
# Out:
# batsmanName
# Usman Ghani                   3
# Vikramjit Singh               5
# Virat Kohli                   3
# Vriitya Aravind               3
# Wanindu Hasaranga de Silva    5
# Wayne Parnell                 2
# Wellington Masakadza          1
# Wessly Madhevere              7
# Yasir Ali                     2
# Zahoor Khan                   0
# Zane Green                    1
# Zawar Farid                   1
# Name: out, dtype: int64

# %% [markdown]
# 4) Batting_Avg = Average runs scored in an innings

# %%
import numpy as np
Total_Runs['Batting_Avg'] =  np.divide(Total_Runs['runs'],Total_Runs['out']).replace([np.inf,-np.inf],0).round(2)
#Total_Runs['out'].apply(lambda x : 0 if x['out']==0  else x['runs']/x['out'])
#Total_Runs.head() #45
Total_Runs.tail(12)
# Out:
#                             runs  out  balls  boundary_runs  battingPos  \
# batsmanName
# Usman Ghani                   59    3     64             26           8
# Vikramjit Singh               57    5     62             32           7
# Virat Kohli                  296    3    217            148          18
# Vriitya Aravind               48    3     71             12          11
# Wanindu Hasaranga de Silva    25    5     34              8          43
# Wayne Parnell                  5    2     13              0          28
# Wellington Masakadza           1    1      7              0           8
# Wessly Madhevere             106    7     83             72          16
# Yasir Ali                      5    2      9              0          19
# Zahoor Khan                    1    0      1              0          11
# Zane Green                     2    1      3              0           8
# Zawar Farid                    2    1      4              0           5
#
# ...

# %%
# import numpy as np
# df1 = pd.DataFrame({'num1' : [10,24,50,45]})

# df2 = pd.DataFrame({'num2' : [2,4,0,5]})
# df3 = np.divide(df1['num1'],df2['num2']).replace(np.inf,0)
# #df4 = (df1['num1'] / df2['num2']).replace(np.inf,0)

# #print(df4)
# print(df3)

# #df4.replace([np.inf, -np.inf], 0, inplace=True)
# #df4
# #df4.astype(int)

# %% [markdown]
# 5) Total balls Faced -> Total number of balls faced by the batsman

# %%
Total_Runs.iloc[-15:]['balls']
# Out:
# batsmanName
# Tom Cooper                    103
# Tony Munyonga                  10
# Tristan Stubbs                 31
# Usman Ghani                    64
# Vikramjit Singh                62
# Virat Kohli                   217
# Vriitya Aravind                71
# Wanindu Hasaranga de Silva     34
# Wayne Parnell                  13
# Wellington Masakadza            7
# Wessly Madhevere               83
# Yasir Ali                       9
# Zahoor Khan                     1
# Zane Green                      3
# Zawar Farid                     4
# Name: balls, dtype: int64

# %% [markdown]
# 6) Strike Rate -> No of runs scored per 100 balls

# %%
#df['Strike Rate'] = (df['Total Runs'] / df['Total Balls Faced']).fillna(0) * 100
#df_batting['Total_Runs'] = df_batting['batsmanName'].map(Total_Runs['runs'])
#df_batting.iloc[:-25]
Total_Runs['Strike_Rate'] = ((Total_Runs['runs'] / Total_Runs['balls']).fillna(0) * 100).round(2)

# %%
Total_Runs.loc[Total_Runs['Strike_Rate']>140]
# Out:
#                      runs  out  balls  boundary_runs  battingPos  match_id  \
# batsmanName
# Alex Hales            212    5    144            136          12         6
# Arshdeep Singh          2    0      1              0          11         1
# Cameron Green           3    1      2              0           2         1
# Chris Woakes            5    0      3              4           8         1
# Curtis Campher        126    5     77             60          32         6
# David Wiese            66    2     42             34          21         3
# Finn Allen             95    5     51             74           5         5
# Glenn Maxwell         118    3     73             80          18         4
# Glenn Phillips        201    5    127            124          20         5
# Haris Rauf             10    1      7              6          30         3
# JJ Smit                39    1     23             24          22         3
# ...

# %% [markdown]
# 7) Batting Position ->  Batting position of a player

# %%
import numpy as np
# Round up the mean to the nearest integer using ceil() func
#batting_position = np.ceil(df_batting.groupby(['batsmanName']).mean('battingPos'))
#batting_position.iloc[-15:]['battingPos']
#batting_position.tail(15)

# %%
Total_Runs['avg_battingPos'] = np.ceil(Total_Runs['battingPos']/Total_Runs['match_id'])
Total_Runs.iloc[-24:][['avg_battingPos','battingPos','match_id']]
# Out:
#                             avg_battingPos  battingPos  match_id
# batsmanName
# Suryakumar Yadav                       4.0          24         6
# Tabraiz Shamsi                        11.0          11         1
# Taskin Ahmed                           9.0          34         4
# Temba Bavuma                           2.0           8         5
# Tendai Chatara                        10.0          30         3
# Tim David                              6.0          12         2
# Tim Pringle                            8.0          44         6
# Tim Southee                            9.0          17         2
# Timm van der Gugten                    8.0           8         1
# Tom Cooper                             5.0          34         8
# Tony Munyonga                          5.0           9         2
# Tristan Stubbs                         6.0          16         3
# Usman Ghani                            3.0           8         3
# ...

# %% [markdown]
# 8) Boundary % -> Percentage of boundaries scored by the Batsman

# %%
Total_Runs['boundaryPerc'] = ((Total_Runs['boundary_runs']/Total_Runs['runs'])*100).round(2) 
Total_Runs.tail(15)
# Out:
#                             runs  out  balls  boundary_runs  battingPos  \
# batsmanName
# Tom Cooper                   107    8    103             46          34
# Tony Munyonga                  7    2     10              4           9
# Tristan Stubbs                31    3     31             14          16
# Usman Ghani                   59    3     64             26           8
# Vikramjit Singh               57    5     62             32           7
# Virat Kohli                  296    3    217            148          18
# Vriitya Aravind               48    3     71             12          11
# Wanindu Hasaranga de Silva    25    5     34              8          43
# Wayne Parnell                  5    2     13              0          28
# Wellington Masakadza           1    1      7              0           8
# Wessly Madhevere             106    7     83             72          16
# Yasir Ali                      5    2      9              0          19
# ...

# %% [markdown]
# 9) Avg. balls Faced -> Average balls faced by the batter in an innings

# %%
# import numpy as np
# avg_ballsFaced = np.ceil(df_batting.groupby(['batsmanName']).mean('balls'))
# avg_ballsFaced.iloc[-15:]['balls']

# %%
Total_Runs['avg_balls_faced'] = np.ceil(Total_Runs['balls']/Total_Runs['match_id'])
Total_Runs.iloc[-15:][['balls','avg_balls_faced','match_id']]
# Out:
#                             balls  avg_balls_faced  match_id
# batsmanName
# Tom Cooper                    103             13.0         8
# Tony Munyonga                  10              5.0         2
# Tristan Stubbs                 31             11.0         3
# Usman Ghani                    64             22.0         3
# Vikramjit Singh                62             13.0         5
# Virat Kohli                   217             37.0         6
# Vriitya Aravind                71             24.0         3
# Wanindu Hasaranga de Silva     34              6.0         6
# Wayne Parnell                  13              4.0         4
# Wellington Masakadza            7              7.0         1
# Wessly Madhevere               83             11.0         8
# Yasir Ali                       9              3.0         3
# Zahoor Khan                     1              1.0         1
# Zane Green                      3              3.0         1
# ...

# %%
Total_Runs.reset_index(inplace=True)
Total_Runs.head()
# Out:
#         batsmanName  runs  out  balls  boundary_runs  battingPos  match_id  \
# 0       Aaron Finch   107    2     97             54           6         3
# 1  Aayan Afzal Khan    24    2     28              4          15         2
# 2        Adam Zampa     1    1      3              0          20         2
# 3      Afif Hossain    95    4     76             42          24         5
# 4     Aiden Markram    99    4     79             58          17         4
#
#    Batting_Avg  Strike_Rate  avg_battingPos  boundaryPerc  avg_balls_faced
# 0        53.50       110.31             2.0         50.47             33.0
# 1        12.00        85.71             8.0         16.67             14.0
# 2         1.00        33.33            10.0          0.00              2.0
# 3        23.75       125.00             5.0         44.21             16.0
# 4        24.75       125.32             5.0         58.59             20.0

# %%
Total_Runs.rename({'match_id':'inningsBatted','batsmanName': 'playerName'}, axis = 1, inplace = True)
Total_Runs.head()
# Out:
#          playerName  runs  out  balls  boundary_runs  battingPos  \
# 0       Aaron Finch   107    2     97             54           6
# 1  Aayan Afzal Khan    24    2     28              4          15
# 2        Adam Zampa     1    1      3              0          20
# 3      Afif Hossain    95    4     76             42          24
# 4     Aiden Markram    99    4     79             58          17
#
#    inningsBatted  Batting_Avg  Strike_Rate  avg_battingPos  boundaryPerc  \
# 0              3        53.50       110.31             2.0         50.47
# 1              2        12.00        85.71             8.0         16.67
# 2              2         1.00        33.33            10.0          0.00
# 3              5        23.75       125.00             5.0         44.21
# 4              4        24.75       125.32             5.0         58.59
#
#    avg_balls_faced
# 0             33.0
# 1             14.0
# 2              2.0
# 3             16.0
# 4             20.0

# %%
df_merge.rename({'batsmanName':'playerName'},axis=1,inplace=True)
df_merge.head()
# Out:
#                   match teamInnings  battingPos              playerName  runs  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen     3
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock     9
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton    20
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard    26
# 4  Namibia Vs Sri Lanka     Namibia           5         Gerhard Erasmus    20
#
#    balls  fours  sixes      SR   match_id_x  out  boundary_runs    team1  \
# 0      6      0      0   50.00  T20I # 1823    1              0  Namibia
# 1      9      1      0  100.00  T20I # 1823    1              4  Namibia
# 2     12      1      2  166.66  T20I # 1823    1             16  Namibia
# 3     24      2      0  108.33  T20I # 1823    1              8  Namibia
# 4     24      0      0   83.33  T20I # 1823    1              0  Namibia
#
# ...

# %%
batting_match = pd.merge(Total_Runs,df_merge,on='playerName')
batting_match.head()
# Out:
#          playerName  runs_x  out_x  balls_x  boundary_runs_x  battingPos_x  \
# 0       Aaron Finch     107      2       97               54             6
# 1  Aayan Afzal Khan      24      2       28                4            15
# 2        Adam Zampa       1      1        3                0            20
# 3      Afif Hossain      95      4       76               42            24
# 4      Afif Hossain      95      4       76               42            24
#
#    inningsBatted  Batting_Avg  Strike_Rate  avg_battingPos  ...  out_y  \
# 0              3        53.50       110.31             2.0  ...      1
# 1              2        12.00        85.71             8.0  ...      1
# 2              2         1.00        33.33            10.0  ...      0
# 3              5        23.75       125.00             5.0  ...      1
# 4              5        23.75       125.00             5.0  ...      1
#
#    boundary_runs_y       team1        team2      winner   margin    ground  \
# ...

# %%
battingAvg_time = batting_match.loc[batting_match['stage']=="Super12",['matchDate','Batting_Avg','match']]
x = battingAvg_time.sort_values('matchDate',ascending=True).groupby('matchDate').sum('Batting_Avg').round(2)
y = battingAvg_time.groupby('matchDate').mean('Batting_Avg').round(2)
y.reset_index(inplace=True)
y
#c = x = battingAvg_time.sort_values('matchDate',ascending=True).groupby('matchDate').count()
#c
# Out:
#      matchDate  Batting_Avg
# 0   2022-10-22        18.99
# 1   2022-10-23        21.44
# 2   2022-10-24        14.94
# 3   2022-10-27        25.12
# 4   2022-10-29        20.50
# 5   2022-10-30        19.44
# 6   2022-10-31        22.57
# 7   2022-11-01        24.33
# 8   2022-11-03        16.38
# 9   2022-11-04        16.66
# 10  2022-11-06        20.20
# 11  2022-11-09        30.61

# %%
y.loc[:,['matchDate','Batting_Avg']].plot()

plt.show()

# %%
# @title matchDate vs Batting_Avg

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['matchDate']
  ys = series['Batting_Avg']
  
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = x.sort_values('matchDate', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('matchDate')
_ = plt.ylabel('Batting_Avg')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'matchDate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[109], line 14
# ...

# %% [markdown]
# ## anchors

# %%
anchors = Total_Runs.loc[(Total_Runs['Batting_Avg']>30) & (Total_Runs['Strike_Rate']>140) & (Total_Runs['inningsBatted']>3) & (Total_Runs['boundaryPerc']>50.00) & (Total_Runs['avg_battingPos']<4),['playerName','Strike_Rate','balls','avg_balls_faced','inningsBatted','Batting_Avg','avg_battingPos','boundaryPerc','runs']]
openers
# Out:
#           playerName  Strike_Rate  balls  avg_balls_faced  inningsBatted  \
# 6         Alex Hales       147.22    144             24.0              6
# 83       Jos Buttler       144.23    156             26.0              6
# 96      Kusal Mendis       142.95    156             20.0              8
# 145  Quinton de Kock       161.04     77             16.0              5
# 152    Rilee Rossouw       169.88     83             21.0              4
#
#      Batting_Avg  avg_battingPos  boundaryPerc  runs
# 6          42.40             2.0         64.15   212
# 83         45.00             1.0         61.33   225
# 96         31.86             2.0         57.40   223
# 145        31.00             2.0         75.81   124
# 152        35.25             3.0         63.83   141

# %%
openers.loc[:,['balls','avg_balls_faced']]
# Out:
#      balls  avg_balls_faced
# 6      144             24.0
# 83     156             26.0
# 96     156             20.0
# 145     77             16.0
# 152     83             21.0

# %%
openers.sort_values(by='runs',ascending=False)
# Out:
#           playerName  Strike_Rate  balls  avg_balls_faced  inningsBatted  \
# 83       Jos Buttler       144.23    156             26.0              6
# 96      Kusal Mendis       142.95    156             20.0              8
# 6         Alex Hales       147.22    144             24.0              6
# 152    Rilee Rossouw       169.88     83             21.0              4
# 145  Quinton de Kock       161.04     77             16.0              5
#
#      Batting_Avg  avg_battingPos  boundaryPerc  runs
# 83         45.00             1.0         61.33   225
# 96         31.86             2.0         57.40   223
# 6          42.40             2.0         64.15   212
# 152        35.25             3.0         63.83   141
# 145        31.00             2.0         75.81   124

# %%
# @title Runs Scored by Each Player

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6, 4))  
sns.barplot(x='playerName', y='runs',hue='playerName', data=openers, palette='crest',legend=False)
plt.xticks(rotation=90)
plt.xlabel('Batsman Name')
plt.ylabel('Runs Scored')
plt.title('Runs Scored by Each Player')
#plt.gca().spines[['top', 'right']].set_visible(False)
#plt.tight_layout()
plt.show()

# %%
# @title Runs Scored by Each Player

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6, 4))  
sns.barplot(x='batsmanName', y='Strike_Rate',hue='batsmanName', data=openers, palette='Blues',legend=False)
plt.xticks(rotation=90)
plt.xlabel('Batsman Name')
plt.ylabel('Strike Rate')
plt.title('Strike Rate of each Batsman')
#plt.gca().spines[['top', 'right']].set_visible(False)
#plt.tight_layout()
plt.show()

# %%
# @title Runs Scored by Each Player

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6, 4))  
sns.barplot(x='playerName', y='inningsBatted',hue='playerName', data=openers, palette='pink',legend=False)
plt.xticks(rotation=90)
plt.xlabel('Batsman Name')
plt.ylabel('Innings Batted')
plt.title('Innings Batted by Each Player')
#plt.gca().spines[['top', 'right']].set_visible(False)
#plt.tight_layout()
plt.show()

# %%
# @title Runs Scored by Each Player

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6, 4))  
sns.barplot(x='playerName', y='boundaryPerc',hue='playerName', data=openers, palette='grey',legend=False)
plt.xticks(rotation=90)
plt.xlabel('Batsman Name')
plt.ylabel('Boundary Percentage')
plt.title('Boundary percentage of Each Player')
#plt.gca().spines[['top', 'right']].set_visible(False)
#plt.tight_layout()
plt.show()

# %%
print(openers.to_string())
# Out:
#           playerName  Strike_Rate  balls  avg_balls_faced  inningsBatted  Batting_Avg  avg_battingPos  boundaryPerc  runs
# 6         Alex Hales       147.22    144             24.0              6        42.40             2.0         64.15   212
# 83       Jos Buttler       144.23    156             26.0              6        45.00             1.0         61.33   225
# 96      Kusal Mendis       142.95    156             20.0              8        31.86             2.0         57.40   223
# 145  Quinton de Kock       161.04     77             16.0              5        31.00             2.0         75.81   124
# 152    Rilee Rossouw       169.88     83             21.0              4        35.25             3.0         63.83   141

# %%
openers.head()
# Out:
#           playerName  Strike_Rate  balls  avg_balls_faced  inningsBatted  \
# 6         Alex Hales       147.22    144             24.0              6
# 83       Jos Buttler       144.23    156             26.0              6
# 96      Kusal Mendis       142.95    156             20.0              8
# 145  Quinton de Kock       161.04     77             16.0              5
# 152    Rilee Rossouw       169.88     83             21.0              4
#
#      Batting_Avg  avg_battingPos  boundaryPerc  runs
# 6          42.40             2.0         64.15   212
# 83         45.00             1.0         61.33   225
# 96         31.86             2.0         57.40   223
# 145        31.00             2.0         75.81   124
# 152        35.25             3.0         63.83   141

# %%
sr = openers.loc[:,['Strike_Rate']]
ba = openers.loc[:,['Batting_Avg']]
sr_list = sr['Strike_Rate'].tolist()
ba_list = ba['Batting_Avg'].tolist()
names = anchors.loc[:,['playerName']]
names_list = names['playerName'].tolist()

#sr.sort_values(by='Strike_Rate',ascending=False)

plt.figure(figsize=(8, 6))  
plt.scatter(ba_list,sr_list,s=1000,c='y',alpha=0.8)

for i, txt in enumerate(names_list):
    plt.annotate(txt, (ba_list[i],sr_list[i]))

plt.xlabel('Batting Average',fontsize=12,)
plt.ylabel('Strike Rate',fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5) 
plt.xlim(min(ba_list) - 5, max(ba_list) + 5)  # Adjust x-axis limits for Batting Average
plt.ylim(min(sr_list) - 5, max(sr_list) + 5)
plt.title('Strike Rate vs Batting Average',fontsize=14)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# %%
plt.plot(ba_list,marker='o')
plt.figure(figsize=(1,0.3))

# %%
Total_Runs['Batting_Avg'].plot(kind='line', figsize=(6, 2), title='Boundary_Runs')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
op = openers = Total_Runs.loc[(Total_Runs['Batting_Avg']>30) & (Total_Runs['Strike_Rate']>140) & (Total_Runs['inningsBatted']>3) & (Total_Runs['boundaryPerc']>50.00) & (Total_Runs['avg_battingPos']<4),['match_id']]

# %%
match = pd.merge(df_batting,df_match,on='match_id')
match.head()
# Out:
#                   match teamInnings  battingPos             batsmanName  runs  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen     3
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock     9
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton    20
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard    26
# 4  Namibia Vs Sri Lanka     Namibia           5         Gerhard Erasmus    20
#
#    balls  fours  sixes      SR     match_id  out  boundary_runs    team1  \
# 0      6      0      0   50.00  T20I # 1823    1              0  Namibia
# 1      9      1      0  100.00  T20I # 1823    1              4  Namibia
# 2     12      1      2  166.66  T20I # 1823    1             16  Namibia
# 3     24      2      0  108.33  T20I # 1823    1              8  Namibia
# 4     24      0      0   83.33  T20I # 1823    1              0  Namibia
#
# ...

# %%
battingPlot = pd.merge(openers)

# %% [markdown]
# ## anchors

# %%
anchors = Total_Runs.loc[(Total_Runs['Batting_Avg']>40) & (Total_Runs['Strike_Rate']>125) & (Total_Runs['inningsBatted']>3) & (Total_Runs['avg_balls_faced']>20) & (Total_Runs['avg_battingPos']>2)]
anchors.reset_index(inplace=True)
anchors.head()
# Out:
#    index        playerName  runs  out  balls  boundary_runs  battingPos  \
# 0     40    Daryl Mitchell   109    2     85             26          21
# 1     64    Glenn Phillips   201    5    127            124          20
# 2    102     Lorcan Tucker   204    5    163            100          21
# 3    174  Suryakumar Yadav   239    4    126            158          24
# 4    188       Virat Kohli   296    3    217            148          18
#
#    inningsBatted  Batting_Avg  Strike_Rate  avg_battingPos  boundaryPerc  \
# 0              4        54.50       128.24             6.0         23.85
# 1              5        40.20       158.27             4.0         61.69
# 2              7        40.80       125.15             3.0         49.02
# 3              6        59.75       189.68             4.0         66.11
# 4              6        98.67       136.41             3.0         50.00
#
#    avg_balls_faced
# 0             22.0
# 1             26.0
# 2             24.0
# ...

# %%
sr = anchors.loc[:,['Strike_Rate']]
ba = anchors.loc[:,['Batting_Avg']]
sr_list = sr['Strike_Rate'].tolist()
ba_list = ba['Batting_Avg'].tolist()
names = anchors.loc[:,['playerName']]
names_list = names['playerName'].tolist()

#sr.sort_values(by='Strike_Rate',ascending=False)

plt.figure(figsize=(8, 6))  
plt.scatter(ba_list,sr_list,s=1000,c='g',alpha=0.8)

for i, txt in enumerate(names_list):
    plt.annotate(txt, (ba_list[i],sr_list[i]))

plt.xlabel('Batting Average',fontsize=12,)
plt.ylabel('Strike Rate',fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5) 
plt.xlim(min(ba_list) - 5, max(ba_list) + 5)  # Adjust x-axis limits for Batting Average
plt.ylim(min(sr_list) - 5, max(sr_list) + 5)
plt.title('Strike Rate vs Batting Average',fontsize=14)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# %%
# @title Runs Scored by Each Player

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6, 4))  
sns.barplot(x='batsmanName', y='Strike_Rate',hue='batsmanName', data=anchors, palette='Blues',legend=False)
plt.xticks(rotation=90)
plt.xlabel('Batsman Name')
plt.ylabel('Strike Rate')
plt.title('Strike Rate of each Batsman')
#plt.gca().spines[['top', 'right']].set_visible(False)
#plt.tight_layout()
plt.show()

# %% [markdown]
# Bowling Summary

# %%
df_bowling = pd.read_csv('E:\\BSc.IT\\TY\\DS Project\\data\\bowling_summary.csv')
df_bowling.head(11)
# Out:
#                    match bowlingTeam                  bowlerName  overs  \
# 0   Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana  ['4']
# 1   Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera  ['4']
# 2   Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan  ['4']
# 3   Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne  ['4']
# 4   Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva  ['4']
# 5   Namibia Vs Sri Lanka     Namibia             Gerhard Erasmus  ['1']
# 6   Namibia Vs Sri Lanka     Namibia                 David Wiese  ['4']
# 7   Namibia Vs Sri Lanka     Namibia             Bernard Scholtz  ['4']
# 8   Namibia Vs Sri Lanka     Namibia                Ben Shikongo  ['3']
# 9   Namibia Vs Sri Lanka     Namibia                     JJ Smit  ['3']
# 10  Namibia Vs Sri Lanka     Namibia                Jan Frylinck  ['4']
#
#     maiden  runs  wickets  economy  zeros  fours  sixes  wides  noBalls  \
# ...

# %%
df_bowling['balls'] = df_bowling['overs1']*6 + df_bowling['overs2']
df_bowling.head(23)
# Out:
#                     match  bowlingTeam                  bowlerName  \
# 0    Namibia Vs Sri Lanka    Sri Lanka          Maheesh Theekshana
# 1    Namibia Vs Sri Lanka    Sri Lanka         Dushmantha Chameera
# 2    Namibia Vs Sri Lanka    Sri Lanka             Pramod Madushan
# 3    Namibia Vs Sri Lanka    Sri Lanka         Chamika Karunaratne
# 4    Namibia Vs Sri Lanka    Sri Lanka  Wanindu Hasaranga de Silva
# 5    Namibia Vs Sri Lanka      Namibia             Gerhard Erasmus
# 6    Namibia Vs Sri Lanka      Namibia                 David Wiese
# 7    Namibia Vs Sri Lanka      Namibia             Bernard Scholtz
# 8    Namibia Vs Sri Lanka      Namibia                Ben Shikongo
# 9    Namibia Vs Sri Lanka      Namibia                     JJ Smit
# 10   Namibia Vs Sri Lanka      Namibia                Jan Frylinck
# 11  U.A.E. Vs Netherlands  Netherlands               Fred Klaassen
# 12  U.A.E. Vs Netherlands  Netherlands                 Tim Pringle
# ...

# %%
df_bowling.head()
# Out:
#                   match bowlingTeam                  bowlerName  overs  \
# 0  Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana  ['4']
# 1  Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera  ['4']
# 2  Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan  ['4']
# 3  Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne  ['4']
# 4  Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva  ['4']
#
#    maiden  runs  wickets  economy  zeros  fours  sixes  wides  noBalls  \
# 0       0    23        1     5.75      7      0      0      2        0
# 1       0    39        1     9.75      6      3      1      2        0
# 2       0    37        2     9.25      6      3      1      0        0
# 3       0    36        1     9.00      7      3      1      1        0
# 4       0    27        1     6.75      8      1      1      0        0
#
#       match_id  overs1  overs2  balls
# 0  T20I # 1823       4       0     24
# ...

# %% [markdown]
# 16. Total Innings Bowled -- Total number of innings bowled by a bowler
#
# Total Innings Bowled = DISTINCTCOUNT(fact_bowling_summary[match_id])

# %%
bowlers = df_bowling.groupby(['bowlerName']).agg({'wickets': 'sum', 'balls': 'sum', 'runs': 'sum','match_id':'count','zeros':'sum'})
bowlers.tail(15)
# Out:
#                             wickets  balls  runs  match_id  zeros
# bowlerName
# Simi Singh                        3     54    78         4     14
# Soumya Sarkar                     1     18    29         1      5
# Tabraiz Shamsi                    4     48    56         2     20
# Taskin Ahmed                      8    108   131         5     64
# Tendai Chatara                    4    138   155         7     58
# Tim Pringle                       3    102   102         6     38
# Tim Southee                       7    104   114         5     52
# Timm van der Gugten               1     36    60         2      7
# Trent Boult                       8    120   148         5     56
# Wanindu Hasaranga de Silva       15    186   199         8     74
# Wayne Parnell                     5     96   102         5     48
# Wellington Masakadza              0     12    12         1      5
# Wessly Madhevere                  0     18    25         2      1
# ...

# %%
bowlers.reset_index(inplace=True)
bowlers.head()
# Out:
#          bowlerName  wickets  balls  runs  match_id  zeros
# 0  Aayan Afzal Khan        2     48    38         3     20
# 1        Adam Zampa        5     72    80         3     24
# 2       Adil Rashid        4    144   147         6     45
# 3      Afif Hossain        1      6    11         1      1
# 4        Ahmed Raza        0      6     9         1      1

# %%
bowlers.rename({'bowlerName':'playerName'},axis=1,inplace=True)
bowlers.head()
# Out:
#          playerName  wickets  balls  runs  match_id  zeros
# 0  Aayan Afzal Khan        2     48    38         3     20
# 1        Adam Zampa        5     72    80         3     24
# 2       Adil Rashid        4    144   147         6     45
# 3      Afif Hossain        1      6    11         1      1
# 4        Ahmed Raza        0      6     9         1      1

# %%
Total_Runs.reset_index(inplace=True)

# %%
Total_Runs.rename({'batsmanName':'playerName'},axis=1,inplace=True)
Total_Runs.head()
# Out:
#          playerName  runs  out  balls  boundary_runs  battingPos  match_id  \
# 0       Aaron Finch   107    2     97             54           6         3
# 1  Aayan Afzal Khan    24    2     28              4          15         2
# 2        Adam Zampa     1    1      3              0          20         2
# 3      Afif Hossain    95    4     76             42          24         5
# 4     Aiden Markram    99    4     79             58          17         4
#
#    Batting_Avg  Strike_Rate
# 0        53.50       110.31
# 1        12.00        85.71
# 2         1.00        33.33
# 3        23.75       125.00
# 4        24.75       125.32

# %%
merged_df = pd.merge(Total_Runs,bowlers,on='playerName',suffixes=('_batsman','_bowler'))
merged_df.head()
# Out:
#          playerName  runs_batsman  out  balls_batsman  boundary_runs  \
# 0  Aayan Afzal Khan            24    2             28              4
# 1        Adam Zampa             1    1              3              0
# 2      Afif Hossain            95    4             76             42
# 3     Aiden Markram            99    4             79             58
# 4      Akeal Hosein            24    1             19              8
#
#    battingPos  inningsBatted  Batting_Avg  Strike_Rate  avg_battingPos  \
# 0          15              2        12.00        85.71             8.0
# 1          20              2         1.00        33.33            10.0
# 2          24              5        23.75       125.00             5.0
# 3          17              4        24.75       125.32             5.0
# 4          16              2        24.00       126.32             8.0
#
#    boundaryPerc  avg_balls_faced  wickets  balls_bowler  runs_bowler  \
# ...

# %%
# @title Runs Scored by Each Player

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6, 4))  
sns.barplot(x='playerName', y='inningsBatted',hue='playerName', data=anchors, palette='grey',legend=False)
plt.xticks(rotation=90)
plt.xlabel('Batsman Name')
plt.ylabel('Innings Batted')
plt.title('Innings Batted of Each Player')
#plt.gca().spines[['top', 'right']].set_visible(False)
#plt.tight_layout()
plt.show()

# %%
# @title Runs Scored by Each Player

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6, 4))  
sns.barplot(x='playerName', y='boundaryPerc',hue='playerName', data=openers, palette='pink',legend=False)
plt.xticks(rotation=90)
plt.xlabel('Batsman Name')
plt.ylabel('Boundary Percentage')
plt.title('Boundary percentage of Each Player')
#plt.gca().spines[['top', 'right']].set_visible(False)
#plt.tight_layout()
plt.show()

# %% [markdown]
# ## Finishers

# %%
finishers = merged_df.loc[(merged_df['Batting_Avg']>25) & (merged_df['Strike_Rate']>130) & (merged_df['inningsBatted']>3) & (merged_df['match_id']>1) & (merged_df['avg_battingPos']>4) & (merged_df['avg_balls_faced']>12)]

# %%
finishers
# Out:
#          playerName  runs_batsman  out  balls_batsman  boundary_runs  \
# 26   Curtis Campher           126    5             77             60
# 38    Glenn Maxwell           118    3             73             80
# 40    Hardik Pandya           128    5             97             70
# 66   Marcus Stoinis           126    3             78             82
# 102   Sikandar Raza           219    8            148            130
#
#      battingPos  inningsBatted  Batting_Avg  Strike_Rate  avg_battingPos  \
# 26           32              6        25.20       163.64             6.0
# 38           18              4        39.33       161.64             5.0
# 40           28              5        25.60       131.96             6.0
# 66           20              4        42.00       161.54             5.0
# 102          39              8        27.38       147.97             5.0
#
#      boundaryPerc  avg_balls_faced  wickets  balls_bowler  runs_bowler  \
# ...

# %%
import matplotlib.pyplot as plt
from adjustText import adjust_text


# Assuming finishers dataframe is already available with columns: playerName, Batting_Avg, and Strike_Rate
sr = finishers.loc[:, ['Strike_Rate']]
ba = finishers.loc[:, ['Batting_Avg']]
sr_list = sr['Strike_Rate'].tolist()
ba_list = ba['Batting_Avg'].tolist()
names = finishers.loc[:, ['playerName']]
names_list = names['playerName'].tolist()

plt.figure(figsize=(8, 6))
plt.scatter(ba_list, sr_list, s=1000, c='skyblue', alpha=1.0)

# List to hold annotation objects
annotations = []
for i, txt in enumerate(names_list):
    annotation = plt.annotate(txt, (ba_list[i], sr_list[i]))
    annotations.append(annotation)

plt.xlabel('Batting Average', fontsize=12)
plt.ylabel('Strike Rate', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.xlim(min(ba_list) - 5, max(ba_list) + 5)  # Adjust x-axis limits for Batting Average
plt.ylim(min(sr_list) - 5, max(sr_list) + 5)  # Adjust y-axis limits for Strike Rate
plt.title('Strike Rate vs Batting Average', fontsize=14)
plt.gca().spines[['top', 'right']].set_visible(False)

# Adjust text to prevent overlap
adjust_text(annotations, arrowprops=dict(arrowstyle='->', color='gray', lw=1))

plt.show()

# %%
# @title Runs Scored by Each Player

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6, 4))  
sns.barplot(x='playerName', y='runs_batsman',hue='playerName', data=finishers, palette='Blues',legend=False)
plt.xticks(rotation=90)
plt.xlabel('Name')
plt.ylabel('Runs Scored')
plt.title('Runs Scored by Each Player')
#plt.gca().spines[['top', 'right']].set_visible(False)
#plt.tight_layout()
plt.show()

# %%
bowlers.rename({'runs':'Runs_conceded','match_id':'inningsBowled','balls':'ballsBowled'},axis=1,inplace=True)
bowlers.head()
# Out:
#          playerName  wickets  ballsBowled  Runs_conceded  inningsBowled  zeros
# 0  Aayan Afzal Khan        2           48             38              3     20
# 1        Adam Zampa        5           72             80              3     24
# 2       Adil Rashid        4          144            147              6     45
# 3      Afif Hossain        1            6             11              1      1
# 4        Ahmed Raza        0            6              9              1      1

# %% [markdown]
# 13. Bowling Economy --> Average number of runs conceded in an over

# %%
bowlers['Economy'] = round(bowlers['Runs_conceded']/ (bowlers['ballsBowled']/6),2)
bowlers.tail()
# Out:
#                playerName  wickets  ballsBowled  Runs_conceded  inningsBowled  \
# 127         Wayne Parnell        5           96            102              5
# 128  Wellington Masakadza        0           12             12              1
# 129      Wessly Madhevere        0           18             25              2
# 130           Zahoor Khan        5           72             57              3
# 131           Zawar Farid        0           17             24              1
#
#      zeros  Economy
# 127     48     6.38
# 128      5     6.00
# 129      1     8.33
# 130     39     4.75
# 131      2     8.47

# %% [markdown]
# 14. Bowling Strike Rate --> Number of balls bowled per wicket

# %%
bowlers['Bowling_Strike_Rate'] = np.divide(bowlers['ballsBowled'],bowlers['wickets']).replace([np.inf, -np.inf],0).round(2)
bowlers.head()
# Out:
#          playerName  wickets  ballsBowled  Runs_conceded  inningsBowled  \
# 0  Aayan Afzal Khan        2           48             38              3
# 1        Adam Zampa        5           72             80              3
# 2       Adil Rashid        4          144            147              6
# 3      Afif Hossain        1            6             11              1
# 4        Ahmed Raza        0            6              9              1
#
#    zeros  Economy  Bowling_Strike_Rate  Bowling_Avg  Dot_Ball
# 0     20     4.75                 24.0        19.00  0.416667
# 1     24     6.67                 14.4        16.00  0.333333
# 2     45     6.12                 36.0        36.75  0.312500
# 3      1    11.00                  6.0        11.00  0.166667
# 4      1     9.00                  0.0         0.00  0.166667

# %%
bowlers.tail()
# Out:
#                playerName  wickets  ballsBowled  Runs_conceded  inningsBowled  \
# 127         Wayne Parnell        5           96            102              5
# 128  Wellington Masakadza        0           12             12              1
# 129      Wessly Madhevere        0           18             25              2
# 130           Zahoor Khan        5           72             57              3
# 131           Zawar Farid        0           17             24              1
#
#      zeros  Economy  Bowling_Strike_Rate
# 127     48     6.38                 19.2
# 128      5     6.00                  0.0
# 129      1     8.33                  0.0
# 130     39     4.75                 14.4
# 131      2     8.47                  0.0

# %% [markdown]
# ## All - Rounders / Lower Order

# %%
para = pd.merge(Total_Runs,bowlers,on='playerName')
para.head()
# Out:
#          playerName  runs  out  balls  boundary_runs  battingPos  \
# 0  Aayan Afzal Khan    24    2     28              4          15
# 1        Adam Zampa     1    1      3              0          20
# 2      Afif Hossain    95    4     76             42          24
# 3     Aiden Markram    99    4     79             58          17
# 4      Akeal Hosein    24    1     19              8          16
#
#    inningsBatted  Batting_Avg  Strike_Rate  avg_battingPos  ...  \
# 0              2        12.00        85.71             8.0  ...
# 1              2         1.00        33.33            10.0  ...
# 2              5        23.75       125.00             5.0  ...
# 3              4        24.75       125.32             5.0  ...
# 4              2        24.00       126.32             8.0  ...
#
#    avg_balls_faced  wickets  ballsBowled  Runs_conceded  inningsBowled  zeros  \
# 0             14.0        2           48             38              3     20
# ...

# %%
allRounders = para.loc[(para['Batting_Avg']>15) & (para['Strike_Rate']>140) & (para['inningsBatted']>2) & (para['avg_battingPos']>4) & (para['inningsBowled']>2) & (para['Economy']<7) & (para['Bowling_Strike_Rate']<20)]
allRounders
# Out:
#            playerName  runs  out  balls  boundary_runs  battingPos  \
# 71   Mitchell Santner    27    1     16             12          21
# 90        Rashid Khan    57    2     32             40          23
# 98        Shadab Khan    98    4     58             58          36
# 102     Sikandar Raza   219    8    148            130          39
#
#      inningsBatted  Batting_Avg  Strike_Rate  avg_battingPos  ...  \
# 71               3        27.00       168.75             7.0  ...
# 90               3        28.50       178.12             8.0  ...
# 98               6        24.50       168.97             6.0  ...
# 102              8        27.38       147.97             5.0  ...
#
#      avg_balls_faced  wickets  ballsBowled  Runs_conceded  inningsBowled  \
# 71               6.0        9          120            129              5
# 90              11.0        4           72             77              3
# 98              10.0       11          156            165              7
# ...

# %% [markdown]
# 15. Bowling Average --> No. of runs allowed per wicket

# %%
bowlers['Bowling_Avg'] = np.divide(bowlers['Runs_conceded'],bowlers['wickets']).replace([np.inf, -np.inf],0)
bowlers.tail()
# Out:
#                playerName  wickets  ballsBowled  Runs_conceded  inningsBowled  \
# 127         Wayne Parnell        5           96            102              5
# 128  Wellington Masakadza        0           12             12              1
# 129      Wessly Madhevere        0           18             25              2
# 130           Zahoor Khan        5           72             57              3
# 131           Zawar Farid        0           17             24              1
#
#      zeros  Economy  Bowling_Strike_Rate  Bowling_Avg  Dot_Ball
# 127     48     6.38                 19.2         20.4  0.500000
# 128      5     6.00                  0.0          0.0  0.416667
# 129      1     8.33                  0.0          0.0  0.055556
# 130     39     4.75                 14.4         11.4  0.541667
# 131      2     8.47                  0.0          0.0  0.117647

# %% [markdown]
# 17. Dot Ball % --> Percentage of dot balls bowled by a bowler

# %%
bowlers['Dot_Ball'] = ((bowlers['zeros']/bowlers['ballsBowled'].replace([np.inf,-np.inf],0))*100).round(2)
bowlers.head()
# Out:
#          playerName  wickets  ballsBowled  Runs_conceded  inningsBowled  \
# 0  Aayan Afzal Khan        2           48             38              3
# 1        Adam Zampa        5           72             80              3
# 2       Adil Rashid        4          144            147              6
# 3      Afif Hossain        1            6             11              1
# 4        Ahmed Raza        0            6              9              1
#
#    zeros  Economy  Bowling_Strike_Rate  Bowling_Avg  Dot_Ball
# 0     20     4.75                 24.0        19.00     41.67
# 1     24     6.67                 14.4        16.00     33.33
# 2     45     6.12                 36.0        36.75     31.25
# 3      1    11.00                  6.0        11.00     16.67
# 4      1     9.00                  0.0         0.00     16.67

# %%
allRounders.loc[:,['Economy','Bowling_Strike_Rate']]
# Out:
#      Economy  Bowling_Strike_Rate
# 71      6.45                13.33
# 90      6.42                18.00
# 98      6.35                14.18
# 102     6.50                14.40

# %%
sr = allRounders.loc[:,['Economy']]
ba = allRounders.loc[:,['Bowling_Strike_Rate']]
sr_list = sr['Economy'].tolist()
ba_list = ba['Bowling_Strike_Rate'].tolist()
names = allRounders.loc[:,['playerName']]
names_list = names['playerName'].tolist()

#sr.sort_values(by='Strike_Rate',ascending=False)

plt.figure(figsize=(8, 6))  
plt.scatter(ba_list,sr_list,s=1000,c='pink',alpha=1)

for i, txt in enumerate(names_list):
    plt.annotate(txt, (ba_list[i],sr_list[i]))

plt.xlabel('Bowling Strike Rate',fontsize=12,)
plt.ylabel('Economy',fontsize=12)
plt.grid(True, linestyle='--', alpha=1) 
plt.xlim(min(ba_list)-0.5 , max(ba_list)+0.5 )  # Adjust x-axis limits for Batting Average
plt.ylim(min(sr_list)-0.5 , max(sr_list)+0.5 )
plt.title('Economy vs Bowling Strike Rate',fontsize=14)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# %%
# @title Runs Scored by Each Player

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6, 4))  
sns.barplot(x='playerName', y='Strike_Rate',hue='playerName', data=allRounders, palette='Blues',legend=False)
plt.xticks(rotation=90)
plt.xlabel('Name')
plt.ylabel('Strike Rate')
plt.title('Strike Rate of each Player')
#plt.gca().spines[['top', 'right']].set_visible(False)
#plt.tight_layout()
plt.show()

# %% [markdown]
# ## Players

# %%
df_players = pd.read_csv("E:\\BSc.IT\\TY\\DS Project\\data\\dim_players.csv")
df_players.head()
# Out:
#                     name        team image    battingStyle  \
# 0  Najmul Hossain Shanto  Bangladesh   NaN   Left hand Bat
# 1          Soumya Sarkar  Bangladesh   NaN   Left hand Bat
# 2             Litton Das  Bangladesh   NaN  Right hand Bat
# 3     Shakib Al Hasan(c)  Bangladesh   NaN   Left hand Bat
# 4           Afif Hossain  Bangladesh   NaN   Left hand Bat
#
#              bowlingStyle          playingRole  \
# 0      Right arm Offbreak     Top order Batter
# 1   Right arm Medium fast  Middle order Batter
# 2                     NaN  Wicketkeeper Batter
# 3  Slow Left arm Orthodox           Allrounder
# 4      Right arm Offbreak           Allrounder
#
#                                          description
# 0  Nazmul Hossain Shanto emerged from an unusual ...
# 1  A rarity among Bangladesh allrounders, top-ord...
# 2  Liton Das is the first wicketkeeper-batsman in...
# 3  When the annals of Bangladesh cricket are sift...
# 4  Bangladesh left-hander Afif Hossain made his T...

# %%
df_players.loc[(df_players['bowlingStyle'].str.contains('Fast',na=False)) ]
# Out:
#                     name          team  \
# 15            Brad Evans      Zimbabwe
# 16       Richard Ngarava      Zimbabwe
# 17   Blessing Muzarabani      Zimbabwe
# 18        Tendai Chatara      Zimbabwe
# 19          Taskin Ahmed    Bangladesh
# 21     Mustafizur Rahman    Bangladesh
# 31   Shaheen Shah Afridi      Pakistan
# 32           Naseem Shah      Pakistan
# 33        Mohammad Wasim      Pakistan
# 34            Haris Rauf      Pakistan
# 35        Ebadot Hossain    Bangladesh
# 53         Lahiru Kumara     Sri Lanka
# 56      Fazalhaq Farooqi   Afghanistan
# 57          Fareed Ahmad   Afghanistan
# 71          Bas de Leede   Netherlands
# 78         Fred Klaassen   Netherlands
# 79     Paul van Meekeren   Netherlands
# 88            Mark Adair       Ireland
# 89        Barry McCarthy       Ireland
# 91           Josh Little       Ireland
# 95            Ben Stokes       England
# 99          Chris Woakes       England
# 100            Mark Wood       England
# ...

# %%
df_players.rename({'name':'playerName'},axis=1,inplace=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 df_players.iloc[:1][2]
#
# ...

# %%
fast_player = pd.merge(bowlers,df_players,on='playerName')
fast_player.head()
# Out:
#          playerName  wickets  ballsBowled  Runs_conceded  inningsBowled  \
# 0  Aayan Afzal Khan        2           48             38              3
# 1        Adam Zampa        5           72             80              3
# 2       Adil Rashid        4          144            147              6
# 3      Afif Hossain        1            6             11              1
# 4        Ahmed Raza        0            6              9              1
#
#    zeros  Economy  Bowling_Strike_Rate  Bowling_Avg  Dot_Ball        team  \
# 0     20     4.75                 24.0        19.00     41.67      U.A.E.
# 1     24     6.67                 14.4        16.00     33.33   Australia
# 2     45     6.12                 36.0        36.75     31.25     England
# 3      1    11.00                  6.0        11.00     16.67  Bangladesh
# 4      1     9.00                  0.0         0.00     16.67      U.A.E.
#
#   image    battingStyle            bowlingStyle         playingRole  \
# ...

# %%
f_bowlers = fast_player.loc[
    (fast_player['Dot_Ball'] > 40) &
    (fast_player['Economy'] < 7) &
    (fast_player['Bowling_Strike_Rate'] < 16) &
    (fast_player['inningsBowled']>4) &
    (fast_player['Bowling_Avg'] < 20) &
    (fast_player['bowlingStyle'].str.contains("fast",case=False,na  =False))]
f_bowlers
# Out:
#               playerName  wickets  ballsBowled  Runs_conceded  inningsBowled  \
# 8          Anrich Nortje       11          105             94              5
# 109           Sam Curran       13          136            148              6
# 112  Shaheen Shah Afridi       11          151            155              7
# 123          Tim Southee        7          104            114              5
#
#      zeros  Economy  Bowling_Strike_Rate  Bowling_Avg  Dot_Ball          team  \
# 8       58     5.37                 9.55     8.545455     55.24  South Africa
# 109     66     6.53                10.46    11.384615     48.53       England
# 112     70     6.16                13.73    14.090909     46.36      Pakistan
# 123     52     6.58                14.86    16.285714     50.00   New Zealand
#
#                                                  image    battingStyle  \
# 8    https://img1.hscicdn.com/image/upload/f_auto,t...  Right hand Bat
# ...

# %%
f_bowlers.loc[:,['Bowling_Strike_Rate','Economy']]
# Out:
#      Bowling_Strike_Rate  Economy
# 8                   9.55     5.37
# 109                10.46     6.53
# 112                13.73     6.16
# 123                14.86     6.58

# %%
sr = f_bowlers.loc[:,['Economy']]
ba = f_bowlers.loc[:,['Bowling_Strike_Rate']]
sr_list = sr['Economy'].tolist()
ba_list = ba['Bowling_Strike_Rate'].tolist()
names = f_bowlers.loc[:,['playerName']]
names_list = names['playerName'].tolist()

#sr.sort_values(by='Strike_Rate',ascending=False)

plt.figure(figsize=(8, 6))  
plt.scatter(ba_list,sr_list,s=1000,c='pink',alpha=1)

for i, txt in enumerate(names_list):
    plt.annotate(txt, (ba_list[i],sr_list[i]))

plt.xlabel('Bowling Strike Rate',fontsize=12,)
plt.ylabel('Economy',fontsize=12)
plt.grid(True, linestyle='--', alpha=1) 
plt.xlim(min(ba_list)-0.2 , max(ba_list)+0.2 )  # Adjust x-axis limits for Batting Average
plt.ylim(min(sr_list)-0.2 , max(sr_list)+0.2 )
plt.title('Economy vs Bowling Strike Rate',fontsize=14)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# %%
# @title Runs Scored by Each Player

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6, 4))  
sns.barplot(x='playerName', y='Dot_Ball',hue='playerName', data=f_bowlers, palette='crest',legend=False)
plt.xticks(rotation=90)
plt.xlabel('Name')
plt.ylabel('Dot Ball(%)')
plt.title('Dot balls played')
#plt.gca().spines[['top', 'right']].set_visible(False)
#plt.tight_layout()
plt.show()

# %%
openers.head()
# Out:
#    index       playerName  Strike_Rate  avg_balls_faced  inningsBatted  \
# 0      6       Alex Hales   147.222222             24.0              6
# 1     83      Jos Buttler   144.230769             26.0              6
# 2     96     Kusal Mendis   142.948718             20.0              8
# 3    145  Quinton de Kock   161.038961             16.0              5
# 4    152    Rilee Rossouw   169.879518             21.0              4
#
#    Batting_Avg  avg_battingPos  boundaryPerc  runs
# 0        42.40             2.0         64.15   212
# 1        45.00             1.0         61.33   225
# 2        31.86             2.0         57.40   223
# 3        31.00             2.0         75.81   124
# 4        35.25             3.0         63.83   141

# %%
df_players['playerName'] = df_players['playerName'].apply(lambda x: x.replace('(c)', ''))

# %%
df = pd.merge(openers,df_players,on = 'playerName',how='left')
x = df.loc[:,['playerName','team','battingStyle','inningsBatted','runs','avg_balls_faced','Strike_Rate','Batting_Avg','avg_battingPos','boundaryPerc']]
x
# Out:
#         playerName          team    battingStyle  inningsBatted  runs  \
# 0       Alex Hales       England  Right hand Bat              6   212
# 1      Jos Buttler       England  Right hand Bat              6   225
# 2     Kusal Mendis     Sri Lanka  Right hand Bat              8   223
# 3  Quinton de Kock  South Africa   Left hand Bat              5   124
# 4    Rilee Rossouw  South Africa   Left hand Bat              4   141
#
#    avg_balls_faced  Strike_Rate  Batting_Avg  avg_battingPos  boundaryPerc
# 0             24.0   147.222222        42.40             2.0         64.15
# 1             26.0   144.230769        45.00             1.0         61.33
# 2             20.0   142.948718        31.86             2.0         57.40
# 3             16.0   161.038961        31.00             2.0         75.81
# 4             21.0   169.879518        35.25             3.0         63.83

# %%
for index, row in df.iterrows():
    print(row['playerName']," ",row['team']," ")
# Out:
# Alex Hales   England
# Jos Buttler   England
# Kusal Mendis   Sri Lanka
# Quinton de Kock   South Africa
# Rilee Rossouw   South Africa
